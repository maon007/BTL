# %%
import functions as f

# %%
# define the input files
files = ['MUSE_20180111_155154_74000_A000.xml', 'MUSE_20180111_155203_15000_A000.xml']

# %%
f.R_calculation(inputs = files, example_of_signal = True, plot_R = True)
# Out:
# Calculation of R wave for the input: MUSE_20180111_155154_74000_A000.xml
# File has been loaded
# Table of leads has been prepared
# Example of a signal for the lead I
# Calculation of the R value...
# Real start is 264, real end is 344, R position is 200.0
# Plotting the R wave for the lead I
# Calculation of R wave for the input: MUSE_20180111_155203_15000_A000.xml
# File has been loaded
# Table of leads has been prepared
# Example of a signal for the lead I
# Calculation of the R value...
# Real start is 280, real end is 300, R position is 200.0
# Plotting the R wave for the lead I

# %%
# create df with the R range for all leads
